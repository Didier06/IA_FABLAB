# %% [markdown]
# <a href="https://colab.research.google.com/github/Didier06/IA_FABLAB/blob/main/Introduction_IA/IA_reseau_2classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Génération de 2 classes de points
# * NbbPoints - nombre total de points à générer.
# * Chaque point a 3 caractéristiques : x, y, et type de classe  (0 pour la première classe et 1 pour la deuxième).

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("2 classes de points", fontsize="small")
centers = [(-4, 2), (0, 0)] # centre des classes
# création des 2 classes
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10)
# X1 contient les coordonnées x,y de chaque popint et Y1 est la classe des points 0 : 1ère classe  et 1 2ème classe
#print(X1)
#print(Y1)

# Xe et Xs sont dans un premier temps les entrées et sorties du réseau
Xe = X1[:,0] # entrée x
Xs = X1[:,1] # entrée y
#print(Xe)
#print()

# tracé des points sur le graphe avec  leur étiquette correspondante en couleur
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.show()

# %% [markdown]
# # Création du réseau séquentiel avec des fonctions d'activation identité (linéaire)

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np

#my_init = initializers.Zeros()
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape doit être égale à 1 + couche 3 neurones units = 3
model.add(Dense(units=1,input_shape=[1],activation= 'linear',kernel_initializer = my_init))
# créer ici votre réseau de neurones avec une couche et un neurone avec une entrée Xe et la sortie Xs
#model.add(Dense(units=1, activation='linear'))
#Création de l'optimiseur ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['mse'])
entree = Xe
sortie = Xs

#Entraînement du réseau 1000 passages (1000 époques)
model.fit(x=entree,y=sortie,epochs=100)

#Affichage des poids
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
prediction = model.predict(xe)

# on obtient une régression linéaire ! on n'a pas séparé les classes de 2 points !
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 20ms/step - loss: 18.7555 - mse: 18.7555
# Epoch 2/100
# 4/4 [==============================] - 0s 16ms/step - loss: 17.6373 - mse: 17.6373
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 16.5019 - mse: 16.5019
# Epoch 4/100
# 4/4 [==============================] - 0s 7ms/step - loss: 15.4282 - mse: 15.4282
# Epoch 5/100
# 4/4 [==============================] - 0s 7ms/step - loss: 14.4299 - mse: 14.4299
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 13.4535 - mse: 13.4535
# Epoch 7/100
# 4/4 [==============================] - 0s 20ms/step - loss: 12.5695 - mse: 12.5695
# Epoch 8/100
# 4/4 [==============================] - 0s 11ms/step - loss: 11.7219 - mse: 11.7219
# Epoch 9/100
# 4/4 [==============================] - 0s 14ms/step - loss: 10.8903 - mse: 10.8903
# Epoch 10/100
# 4/4 [==============================] - 0s 14ms/step - loss: 10.1231 - mse: 10.1231
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 9.4357 - mse: 9.4357
# Epoch 12/100
# 4/4 [==============================] - 0s 12ms/step - loss: 8.7308 - mse: 8.7308
# Epoch 13/100
# 4/4 [==============================] - 0s 10ms/step - loss: 8.1030 - mse: 8.1030
# Epoch 14/100
# 4/4 [==============================] - 0s 10ms/step - loss: 7.4998 - mse: 7.4998
# Epoch 15/100
# 4/4 [==============================] - 0s 16ms/step - loss: 6.9448 - mse: 6.9448
# Epoch 16/100
# 4/4 [==============================] - 0s 18ms/step - loss: 6.4654 - mse: 6.4654
# Epoch 17/100
# 4/4 [==============================] - 0s 15ms/step - loss: 5.9882 - mse: 5.9882
# Epoch 18/100
# 4/4 [==============================] - 0s 18ms/step - loss: 5.5401 - mse: 5.5401
# Epoch 19/100
# 4/4 [==============================] - 0s 9ms/step - loss: 5.1598 - mse: 5.1598
# Epoch 20/100
# 4/4 [==============================] - 0s 29ms/step - loss: 4.7977 - mse: 4.7977
# Epoch 21/100
# 4/4 [==============================] - 0s 15ms/step - loss: 4.4512 - mse: 4.4512
# Epoch 22/100
# 4/4 [==============================] - 0s 9ms/step - loss: 4.1484 - mse: 4.1484
# Epoch 23/100
# 4/4 [==============================] - 0s 19ms/step - loss: 3.8820 - mse: 3.8820
# Epoch 24/100
# 4/4 [==============================] - 0s 19ms/step - loss: 3.6254 - mse: 3.6254
# Epoch 25/100
# 4/4 [==============================] - 0s 21ms/step - loss: 3.4229 - mse: 3.4229
# Epoch 26/100
# 4/4 [==============================] - 0s 19ms/step - loss: 3.2161 - mse: 3.2161
# Epoch 27/100
# 4/4 [==============================] - 0s 16ms/step - loss: 3.0485 - mse: 3.0485
# Epoch 28/100
# 4/4 [==============================] - 0s 25ms/step - loss: 2.8908 - mse: 2.8908
# Epoch 29/100
# 4/4 [==============================] - 0s 20ms/step - loss: 2.7456 - mse: 2.7456
# Epoch 30/100
# 4/4 [==============================] - 0s 24ms/step - loss: 2.6214 - mse: 2.6214
# Epoch 31/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.5109 - mse: 2.5109
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 2.4184 - mse: 2.4184
# Epoch 33/100
# 4/4 [==============================] - 0s 14ms/step - loss: 2.3282 - mse: 2.3282
# Epoch 34/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.2550 - mse: 2.2550
# Epoch 35/100
# 4/4 [==============================] - 0s 17ms/step - loss: 2.1758 - mse: 2.1758
# Epoch 36/100
# 4/4 [==============================] - 0s 14ms/step - loss: 2.1121 - mse: 2.1121
# Epoch 37/100
# 4/4 [==============================] - 0s 19ms/step - loss: 2.0510 - mse: 2.0510
# Epoch 38/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.9969 - mse: 1.9969
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.9454 - mse: 1.9454
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.8961 - mse: 1.8961
# Epoch 41/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.8541 - mse: 1.8541
# Epoch 42/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.8143 - mse: 1.8143
# Epoch 43/100
# 4/4 [==============================] - 0s 20ms/step - loss: 1.7793 - mse: 1.7793
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.7452 - mse: 1.7452
# Epoch 45/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.7194 - mse: 1.7194
# Epoch 46/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.6966 - mse: 1.6966
# Epoch 47/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6745 - mse: 1.6745
# Epoch 48/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6535 - mse: 1.6535
# Epoch 49/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.6357 - mse: 1.6357
# Epoch 50/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.6202 - mse: 1.6202
# Epoch 51/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.6030 - mse: 1.6030
# Epoch 52/100
# 4/4 [==============================] - 0s 25ms/step - loss: 1.5831 - mse: 1.5831
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.5671 - mse: 1.5671
# Epoch 54/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.5517 - mse: 1.5517
# Epoch 55/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5375 - mse: 1.5375
# Epoch 56/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.5239 - mse: 1.5239
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.5126 - mse: 1.5126
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.5038 - mse: 1.5038
# Epoch 59/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.4942 - mse: 1.4942
# Epoch 60/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.4847 - mse: 1.4847
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.4782 - mse: 1.4782
# Epoch 62/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.4700 - mse: 1.4700
# Epoch 63/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.4622 - mse: 1.4622
# Epoch 64/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.4547 - mse: 1.4547
# Epoch 65/100
# 4/4 [==============================] - 0s 31ms/step - loss: 1.4485 - mse: 1.4485
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.4431 - mse: 1.4431
# Epoch 67/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.4372 - mse: 1.4372
# Epoch 68/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4321 - mse: 1.4321
# Epoch 69/100
# 4/4 [==============================] - 0s 18ms/step - loss: 1.4265 - mse: 1.4265
# Epoch 70/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4204 - mse: 1.4204
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4143 - mse: 1.4143
# Epoch 72/100
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4087 - mse: 1.4087
# Epoch 73/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.4031 - mse: 1.4031
# Epoch 74/100
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3981 - mse: 1.3981
# Epoch 75/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3926 - mse: 1.3926
# Epoch 76/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3880 - mse: 1.3880
# Epoch 77/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3839 - mse: 1.3839
# Epoch 78/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3799 - mse: 1.3799
# Epoch 79/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3766 - mse: 1.3766
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3726 - mse: 1.3726
# Epoch 81/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3688 - mse: 1.3688
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3661 - mse: 1.3661
# Epoch 83/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.3630 - mse: 1.3630
# Epoch 84/100
# 4/4 [==============================] - 0s 32ms/step - loss: 1.3605 - mse: 1.3605
# Epoch 85/100
# 4/4 [==============================] - 0s 24ms/step - loss: 1.3579 - mse: 1.3579
# Epoch 86/100
# 4/4 [==============================] - 0s 28ms/step - loss: 1.3548 - mse: 1.3548
# Epoch 87/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3518 - mse: 1.3518
# Epoch 88/100
# 4/4 [==============================] - 0s 19ms/step - loss: 1.3499 - mse: 1.3499
# Epoch 89/100
# 4/4 [==============================] - 0s 34ms/step - loss: 1.3468 - mse: 1.3468
# Epoch 90/100
# 4/4 [==============================] - 0s 10ms/step - loss: 1.3440 - mse: 1.3440
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3415 - mse: 1.3415
# Epoch 92/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3387 - mse: 1.3387
# Epoch 93/100
# 4/4 [==============================] - 0s 9ms/step - loss: 1.3356 - mse: 1.3356
# Epoch 94/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3331 - mse: 1.3331
# Epoch 95/100
# 4/4 [==============================] - 0s 28ms/step - loss: 1.3307 - mse: 1.3307
# Epoch 96/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3279 - mse: 1.3279
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3257 - mse: 1.3257
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3238 - mse: 1.3238
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.3217 - mse: 1.3217
# Epoch 100/100
# 4/4 [==============================] - 0s 14ms/step - loss: 1.3193 - mse: 1.3193
#
# Weights:
#
# [array([[-0.31664652]], dtype=float32), array([0.51385385], dtype=float32)]
# 2/2 [==============================] - 1s 12ms/step

# %% [markdown]
# # Retraçons les points et le droite obtenue :

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("Two classes", fontsize="small")
centers = [(-4, 2), (0, 0)]
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10,center_box=(-10.0, 10.0))

Xe = X1[:,0]
Xs = X1[:,1]

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.plot(liste_x,prediction,color = 'r')
model.summary()
plt.show()
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Comment modifier le réseau de neurones pour séparer les 2 classes ?
#
# * Maintenant les données d'entrée sont de dimension 2, en entrée on met x et y c'est à dire X1
# * Le réseau comporte une seule couche d'entrée comportant un seul neurone. La fonction d'activation est la fonction sigmoide.
# * En sortie (output) on met la classe de Y1 dimension 1.

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np

#my_init = initializers.Zeros()
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=1,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))

#Création du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy']) # on compile mais on sauve l'historique d'apprentissage du réseau
# on pourra comme ça tracer lles graphiques d'évolution des pertes et de la précision.

# entrée X1 de dimension 2 (x, y)
entree = X1
# sortie de dimension  1 (classe bipolaire)
sortie = Y1

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)

#Print weights
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire l'appartenance de points à un classe :
#print(X1)
A= [[2,2]]
B= [[-4,2]]
print(model.predict(A))
print(model.predict(B))
#print(A[0][1]) # valeur x de A

print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 8ms/step - loss: 0.1931 - accuracy: 0.6900
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1837 - accuracy: 0.7100
# Epoch 3/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1756 - accuracy: 0.7100
# Epoch 4/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1685 - accuracy: 0.7200
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1617 - accuracy: 0.7500
# Epoch 6/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1563 - accuracy: 0.7600
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1501 - accuracy: 0.7600
# Epoch 8/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1449 - accuracy: 0.7600
# Epoch 9/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1397 - accuracy: 0.7700
# Epoch 10/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1351 - accuracy: 0.7700
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1307 - accuracy: 0.7700
# Epoch 12/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1258 - accuracy: 0.7800
# Epoch 13/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1214 - accuracy: 0.7800
# Epoch 14/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1168 - accuracy: 0.7900
# Epoch 15/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1124 - accuracy: 0.8000
# Epoch 16/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1081 - accuracy: 0.8100
# Epoch 17/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1038 - accuracy: 0.8200
# Epoch 18/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1003 - accuracy: 0.8400
# Epoch 19/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0967 - accuracy: 0.8600
# Epoch 20/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0934 - accuracy: 0.8700
# Epoch 21/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0899 - accuracy: 0.8800
# Epoch 22/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0868 - accuracy: 0.8900
# Epoch 23/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0837 - accuracy: 0.9000
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0807 - accuracy: 0.9000
# Epoch 25/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0778 - accuracy: 0.9100
# Epoch 26/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0750 - accuracy: 0.9100
# Epoch 27/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0723 - accuracy: 0.9100
# Epoch 28/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0697 - accuracy: 0.9200
# Epoch 29/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0671 - accuracy: 0.9300
# Epoch 30/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0647 - accuracy: 0.9400
# Epoch 31/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9400
# Epoch 32/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0605 - accuracy: 0.9400
# Epoch 33/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0585 - accuracy: 0.9400
# Epoch 34/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0567 - accuracy: 0.9400
# Epoch 35/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0547 - accuracy: 0.9400
# Epoch 36/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0529 - accuracy: 0.9400
# Epoch 37/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0512 - accuracy: 0.9400
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0494 - accuracy: 0.9500
# Epoch 39/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0481 - accuracy: 0.9500
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0465 - accuracy: 0.9600
# Epoch 41/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0450 - accuracy: 0.9600
# Epoch 42/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0438 - accuracy: 0.9700
# Epoch 43/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0424 - accuracy: 0.9700
# Epoch 44/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0413 - accuracy: 0.9700
# Epoch 45/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0401 - accuracy: 0.9700
# Epoch 46/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0391 - accuracy: 0.9700
# Epoch 47/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0381 - accuracy: 0.9800
# Epoch 48/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0373 - accuracy: 0.9800
# Epoch 49/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0364 - accuracy: 0.9800
# Epoch 50/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0355 - accuracy: 0.9800
# Epoch 51/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0347 - accuracy: 0.9800
# Epoch 52/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0339 - accuracy: 0.9800
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0332 - accuracy: 0.9800
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0326 - accuracy: 0.9800
# Epoch 55/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0320 - accuracy: 0.9800
# Epoch 56/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0313 - accuracy: 0.9800
# Epoch 57/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0307 - accuracy: 0.9800
# Epoch 58/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0300 - accuracy: 0.9800
# Epoch 59/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0294 - accuracy: 0.9800
# Epoch 60/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0288 - accuracy: 0.9800
# Epoch 61/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0284 - accuracy: 0.9800
# Epoch 62/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0277 - accuracy: 0.9800
# Epoch 63/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0271 - accuracy: 0.9800
# Epoch 64/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0266 - accuracy: 0.9800
# Epoch 65/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0262 - accuracy: 0.9800
# Epoch 66/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0258 - accuracy: 0.9800
# Epoch 67/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0253 - accuracy: 0.9800
# Epoch 68/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0249 - accuracy: 0.9800
# Epoch 69/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0245 - accuracy: 0.9800
# Epoch 70/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0241 - accuracy: 0.9800
# Epoch 71/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0237 - accuracy: 0.9900
# Epoch 72/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0233 - accuracy: 0.9900
# Epoch 73/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0230 - accuracy: 0.9900
# Epoch 74/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0227 - accuracy: 0.9900
# Epoch 75/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0223 - accuracy: 0.9900
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0220 - accuracy: 0.9900
# Epoch 77/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0217 - accuracy: 0.9900
# Epoch 78/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0213 - accuracy: 0.9900
# Epoch 79/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0211 - accuracy: 0.9900
# Epoch 80/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0208 - accuracy: 0.9900
# Epoch 81/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0206 - accuracy: 0.9900
# Epoch 82/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0204 - accuracy: 0.9900
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0202 - accuracy: 0.9900
# Epoch 84/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0200 - accuracy: 0.9900
# Epoch 85/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0197 - accuracy: 0.9900
# Epoch 86/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0195 - accuracy: 0.9900
# Epoch 87/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0193 - accuracy: 0.9900
# Epoch 88/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0191 - accuracy: 0.9900
# Epoch 89/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9900
# Epoch 90/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0186 - accuracy: 0.9900
# Epoch 91/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0184 - accuracy: 0.9900
# Epoch 92/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0182 - accuracy: 0.9900
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0169 - accuracy: 0.9900
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0168 - accuracy: 0.9900
#
# Weights:
#
# [array([[ 1.065097 ],
#        [-0.5986533]], dtype=float32), array([2.1715755], dtype=float32)]
# 1/1 [==============================] - 0s 61ms/step
# [[0.95707643]]
# 1/1 [==============================] - 0s 34ms/step
# [[0.03605047]]
# prediction A :
# 1/1 [==============================] - 0s 34ms/step
# [[0.95707643]]
# prédiction B :
# 1/1 [==============================] - 0s 37ms/step
# [[0.03605047]]

# %% [markdown]
# # Tracé des graphes avec deux points de tests : A et B

# %%
print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)

ax =plt.subplot(111)
plt.title("2 classes", fontsize="small")

#print(A)
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.scatter(A[0][0], A[0][1], marker="o",c='red', s=40, edgecolor="red")
plt.scatter(B[0][0], B[0][1], marker="o",c='blue', s=40, edgecolor="blue")

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
Ylim = (-xe*1.0792954 - 2.191928)/(-0.56038827)

plt.plot(xe,Ylim,color = 'r')
#model.summary()
plt.show()
# Out:
# prediction A :
# 1/1 [==============================] - 0s 37ms/step
# [[0.95707643]]
# prédiction B :
# 1/1 [==============================] - 0s 36ms/step
# [[0.03605047]]

# %% [markdown]
# # Visualisons l'évolution des erreurs et de la précision du modèle sur les données d'entrainement

# %%
# list all data in history

# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(history.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(history.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Exemple avec 3 classes ...
#
# * Combien de neurones doit comporter la couche d'entrée pour obtenir un résultat convenable ?
# Essayer de modifier le nombre de neurones de la couche d'entrée....
# La couche de sortie doit comporter obligatoirement 3 neurones car on utilise la fonction d'activation softmax et il y a 3 classes

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import initializers
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical
import numpy as np
#from sklearn.cluster import kmeans_plusplus
from sklearn.datasets import make_blobs

# Generate sample data
n_samples = 4000
n_components = 3

X, y_true = make_blobs(
    n_samples=n_samples, centers=n_components, cluster_std=0.60, random_state=0
)

print('y_true :')
print(y_true)
#my_init = initializers.Zeros()
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=128,input_shape=[2],activation= 'relu',kernel_initializer = my_init))
#La couche de sortie, units vaut 3 mais activation softmax
model.add(Dense(units=3, activation='softmax'))

#Optimisation du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='categorical_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  3 (3 classes)
sortie = to_categorical(y_true) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 0 0
# 1 >  1 0 0    vecteur (y_true) > matrice binaire (sortie)
# 2 >  0 1 0


#Entraînement du réseau ? passages
model.fit(x=entree,y=sortie,epochs=20,verbose =0)

#Print weights
#print("")
#print("Weights: \n")
#print(model.get_weights())

#Prediction
A= [[2,2.1]]
B= [[-2,3]]
C= [[0,3.2]]
Apred = model.predict(A)
Bpred = model.predict(B)
Cpred = model.predict(C)

#Affichage des prédictions
#print(model.predict(B))
#print(A[0][1])

print('prediction A :')
print(f"[{Apred[0][0]:.2f},{Apred[0][1]:.2f},{Apred[0][2]:.2f}]")

print('prédiction B :')
print(f"[{Bpred[0][0]:.2f},{Bpred[0][1]:.2f},{Bpred[0][2]:.2f}]")

print('prédiction C :')
print(f"[{Cpred[0][0]:.2f},{Cpred[0][1]:.2f},{Cpred[0][2]:.2f}]")

# Tracés des points avec les prédistions pour A, B et C
plt.figure(figsize=(8, 8))
plt.subplot(111)

#colors = ["#4EACC5", "#FF9C34", "#4E9A06"]
colors = ["red", "green", "blue"]

for k, col in enumerate(colors):# k index , col couleur
    cluster_data = (y_true == k)# cluster succession de valeurs vraies ou fausses
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1], c=col, marker=".", s=10)# X[cluster_data, 0] prend les valeurs X[i,0] pour lesquelles cluster_data[i]=True
plt.scatter(A[0][0], A[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(B[0][0], B[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(C[0][0], C[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.text(2, 1.6, f"[{Apred[0][0]:.1f},{Apred[0][1]:.1f},{Apred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(-2, 2.6, f"[{Bpred[0][0]:.1f},{Bpred[0][1]:.1f},{Bpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(0, 3.5, f"[{Cpred[0][0]:.1f},{Cpred[0][1]:.1f},{Cpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')

plt.title("3 classes", fontsize="small")
plt.show()
# Out:
# y_true :
# [2 2 0 ... 0 2 1]
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 55ms/step
# prediction A :
# [0.00,1.00,0.00]
# prédiction B :
# [0.00,0.00,1.00]
# prédiction C :
# [0.08,0.00,0.92]

# %% [markdown]
# # Traçons les différents domaines ....

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=200,alpha=0.2,seuil=0.45):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha),(0, 0, 1,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        bounds = [0, 0.5, 1]
        norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)

    for i in range(0,3):
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.1f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    ax.scatter(X[:,0], X[:,1], c=y, lw=1,marker=".", s=10)

    return fig, ax

plot_decision_boundary2(entree, sortie, model, alpha=0.2)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.8)
# Out:
# 1250/1250 [==============================] - 2s 2ms/step
# 1250/1250 [==============================] - 2s 1ms/step
# 1250/1250 [==============================] - 2s 1ms/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)

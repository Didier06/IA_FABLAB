# %% [markdown]
# <a href="https://colab.research.google.com/github/Didier06/IA_FABLAB/blob/main/Introduction_IA/IA_reseau_2classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Génération de 2 classes de points
# * NbbPoints - nombre total de points à générer.
# * Chaque point a 3 caractéristiques : x, y, et type de classe  (0 pour la première classe et 1 pour la deuxième).

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("2 classes de points", fontsize="small")
centers = [(-4, 2), (0, 0)] # centre des classes
# création des 2 classes
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10)
# X1 contient les coordonnées x,y de chaque popint et Y1 est la classe des points 0 : 1ère classe  et 1 2ème classe
#print(X1)
#print(Y1)

# Xe et Xs sont dans un premier temps les entrées et sorties du réseau
Xe = X1[:,0] # entrée x
Xs = X1[:,1] # entrée y
#print(Xe)
#print()

# tracé des points sur le graphe avec  leur étiquette correspondante en couleur
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.show()

# %% [markdown]
# # Création du réseau séquentiel avec des fonctions d'activation identité (linéaire)

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np

#my_init = initializers.Zeros()
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape doit être égale à 1 + couche 3 neurones units = 3
model.add(Dense(units=1,input_shape=[1],activation= 'linear',kernel_initializer = my_init))
# créer ici votre réseau de neurones avec une couche et un neurone avec une entrée Xe et la sortie Xs
#model.add(Dense(units=1, activation='linear'))
#Création de l'optimiseur ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['mse'])
entree = Xe
sortie = Xs

#Entraînement du réseau 1000 passages (1000 époques)
model.fit(x=entree,y=sortie,epochs=100)

#Affichage des poids
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
prediction = model.predict(xe)

# on obtient une régression linéaire ! on n'a pas séparé les classes de 2 points !
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 18.8124 - mse: 18.8124
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 17.6160 - mse: 17.6160
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 16.5320 - mse: 16.5320
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 15.4897 - mse: 15.4897
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 14.4776 - mse: 14.4776
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 13.5358 - mse: 13.5358
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 12.5839 - mse: 12.5839
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 11.7526 - mse: 11.7526
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.9042 - mse: 10.9042
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.1721 - mse: 10.1721
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 9.4559 - mse: 9.4559
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.7987 - mse: 8.7987
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.1982 - mse: 8.1982
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.6227 - mse: 7.6227
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.0650 - mse: 7.0650
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.5782 - mse: 6.5782
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 6.1216 - mse: 6.1216
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 5.6903 - mse: 5.6903
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 5.2791 - mse: 5.2791
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.9145 - mse: 4.9145
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.5784 - mse: 4.5784
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.2760 - mse: 4.2760
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0123 - mse: 4.0123
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7573 - mse: 3.7573
# Epoch 25/100
# 4/4 [==============================] - 0s 1ms/step - loss: 3.5482 - mse: 3.5482
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.3364 - mse: 3.3364
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.1272 - mse: 3.1272
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.9569 - mse: 2.9569
# Epoch 29/100
# 4/4 [==============================] - 0s 1ms/step - loss: 2.8078 - mse: 2.8078
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.6808 - mse: 2.6808
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5575 - mse: 2.5575
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.4541 - mse: 2.4541
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3496 - mse: 2.3496
# Epoch 34/100
# 4/4 [==============================] - 0s 1ms/step - loss: 2.2573 - mse: 2.2573
# Epoch 35/100
# 4/4 [==============================] - 0s 1ms/step - loss: 2.1746 - mse: 2.1746
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.1132 - mse: 2.1132
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0468 - mse: 2.0468
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.9942 - mse: 1.9942
# Epoch 39/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.9374 - mse: 1.9374
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8911 - mse: 1.8911
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.8458 - mse: 1.8458
# Epoch 42/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.8113 - mse: 1.8113
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7723 - mse: 1.7723
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7436 - mse: 1.7436
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.7162 - mse: 1.7162
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6914 - mse: 1.6914
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6682 - mse: 1.6682
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6485 - mse: 1.6485
# Epoch 49/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.6266 - mse: 1.6266
# Epoch 50/100
# 4/4 [==============================] - 0s 797us/step - loss: 1.6076 - mse: 1.6076
# Epoch 51/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5932 - mse: 1.5932
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5782 - mse: 1.5782
# Epoch 53/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5643 - mse: 1.5643
# Epoch 54/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.5499 - mse: 1.5499
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5376 - mse: 1.5376
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5259 - mse: 1.5259
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5148 - mse: 1.5148
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.5040 - mse: 1.5040
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4928 - mse: 1.4928
# Epoch 60/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4825 - mse: 1.4825
# Epoch 61/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4727 - mse: 1.4727
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4640 - mse: 1.4640
# Epoch 63/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4563 - mse: 1.4563
# Epoch 64/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4477 - mse: 1.4477
# Epoch 65/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.4419 - mse: 1.4419
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4358 - mse: 1.4358
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4306 - mse: 1.4306
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4233 - mse: 1.4233
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4203 - mse: 1.4203
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.4150 - mse: 1.4150
# Epoch 71/100
# 4/4 [==============================] - 0s 935us/step - loss: 1.4102 - mse: 1.4102
# Epoch 72/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.4052 - mse: 1.4052
# Epoch 73/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.4006 - mse: 1.4006
# Epoch 74/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3954 - mse: 1.3954
# Epoch 75/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3924 - mse: 1.3924
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3883 - mse: 1.3883
# Epoch 77/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3828 - mse: 1.3828
# Epoch 78/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3799 - mse: 1.3799
# Epoch 79/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3745 - mse: 1.3745
# Epoch 80/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3707 - mse: 1.3707
# Epoch 81/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3666 - mse: 1.3666
# Epoch 82/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3630 - mse: 1.3630
# Epoch 83/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3595 - mse: 1.3595
# Epoch 84/100
# 4/4 [==============================] - 0s 0s/step - loss: 1.3560 - mse: 1.3560
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.3524 - mse: 1.3524
# Epoch 86/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3495 - mse: 1.3495
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3458 - mse: 1.3458
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3428 - mse: 1.3428
# Epoch 89/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3402 - mse: 1.3402
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3371 - mse: 1.3371
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3338 - mse: 1.3338
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3306 - mse: 1.3306
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3272 - mse: 1.3272
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3238 - mse: 1.3238
# Epoch 95/100
# 4/4 [==============================] - 0s 783us/step - loss: 1.3205 - mse: 1.3205
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3177 - mse: 1.3177
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3153 - mse: 1.3153
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3133 - mse: 1.3133
# Epoch 99/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3114 - mse: 1.3114
# Epoch 100/100
# 4/4 [==============================] - 0s 1ms/step - loss: 1.3086 - mse: 1.3086
#
# Weights:
#
# [array([[-0.3322063]], dtype=float32), array([0.48839337], dtype=float32)]
# 2/2 [==============================] - 0s 508us/step

# %% [markdown]
# # Retraçons les points et le droite obtenue :

# %%
import matplotlib.pyplot as plt
#from pandas import DataFrame as df
from sklearn.datasets import make_blobs, make_classification, make_gaussian_quantiles

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)
Nb_points = 100
plt.subplot(111)
plt.title("Two classes", fontsize="small")
centers = [(-4, 2), (0, 0)]
X1, Y1 = make_blobs(n_samples = Nb_points, cluster_std= 1, n_features=2, centers=centers, random_state=10,center_box=(-10.0, 10.0))

Xe = X1[:,0]
Xs = X1[:,1]

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")

plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.plot(liste_x,prediction,color = 'r')
model.summary()
plt.show()
plt.show()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Comment modifier le réseau de neurones pour séparer les 2 classes ?
#
# * Maintenant les données d'entrée sont de dimension 2, en entrée on met x et y c'est à dire X1
# * Le réseau comporte une seule couche d'entrée comportant un seul neurone. La fonction d'activation est la fonction sigmoide.
# * En sortie (output) on met la classe de Y1 dimension 1.

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import initializers
from keras.optimizers import SGD, Adam
import numpy as np

#my_init = initializers.Zeros()
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)
#normalizer = preprocessing.Normalization()
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=1,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))

#Création du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy']) # on compile mais on sauve l'historique d'apprentissage du réseau
# on pourra comme ça tracer lles graphiques d'évolution des pertes et de la précision.

# entrée X1 de dimension 2 (x, y)
entree = X1
# sortie de dimension  1 (classe bipolaire)
sortie = Y1

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)

#Print weights
print("")
print("Weights: \n")
print(model.get_weights())

#Prédire l'appartenance de points à un classe :
#print(X1)
A= [[2,2]]
B= [[-4,2]]
print(model.predict(A))
print(model.predict(B))
#print(A[0][1]) # valeur x de A

print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2267 - accuracy: 0.6900
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2173 - accuracy: 0.7100
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 0.7100
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2013 - accuracy: 0.7200
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.7400
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1878 - accuracy: 0.7500
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1829 - accuracy: 0.7600
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1782 - accuracy: 0.7600
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1731 - accuracy: 0.7600
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1684 - accuracy: 0.7600
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1637 - accuracy: 0.7600
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1593 - accuracy: 0.7600
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.7600
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1503 - accuracy: 0.7600
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1458 - accuracy: 0.7900
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1411 - accuracy: 0.7900
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.8000
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.8100
# Epoch 19/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.8100
# Epoch 20/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1233 - accuracy: 0.8200
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1181 - accuracy: 0.8300
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.8300
# Epoch 23/100
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1096 - accuracy: 0.8300
# Epoch 24/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1061 - accuracy: 0.8300
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.8600
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.8600
# Epoch 27/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0941 - accuracy: 0.8600
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0901 - accuracy: 0.8600
# Epoch 29/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 0.8800
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0816 - accuracy: 0.9000
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0785 - accuracy: 0.9100
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0746 - accuracy: 0.9100
# Epoch 33/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0714 - accuracy: 0.9100
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9100
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9100
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0618 - accuracy: 0.9300
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9300
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0548 - accuracy: 0.9400
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9400
# Epoch 40/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9400
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9500
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0425 - accuracy: 0.9600
# Epoch 43/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9700
# Epoch 44/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9700
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9700
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9800
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9800
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9800
# Epoch 49/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9800
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0305 - accuracy: 0.9800
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9800
# Epoch 52/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9800
# Epoch 53/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0278 - accuracy: 0.9800
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9800
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9800
# Epoch 56/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9800
# Epoch 57/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9800
# Epoch 58/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9800
# Epoch 59/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9800
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9900
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9900
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9900
# Epoch 63/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9900
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 0.9900
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9900
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9900
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9900
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9900
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9900
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0205 - accuracy: 0.9900
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0203 - accuracy: 0.9900
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9900
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9900
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9900
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9900
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9900
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9900
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 0.9900
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9900
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9900
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9900
# Epoch 82/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9900
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9900
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9900
# Epoch 85/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9900
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9900
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.9900
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9900
# Epoch 89/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.9900
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9900
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9900
# Epoch 92/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9900
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9900
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9900
# Epoch 95/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9900
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9900
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9900
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9900
# Epoch 99/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9900
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9900
#
# Weights:
#
# [array([[ 0.5628945 ],
#        [-0.37883165]], dtype=float32), array([2.3247657], dtype=float32)]
# 1/1 [==============================] - 0s 59ms/step
# [[0.9366059]]
# 1/1 [==============================] - 0s 33ms/step
# [[0.3352631]]
# prediction A :
# 1/1 [==============================] - 0s 37ms/step
# [[0.9366059]]
# prédiction B :
# 1/1 [==============================] - 0s 34ms/step
# [[0.3352631]]

# %% [markdown]
# # Tracé des graphes avec deux points de tests : A et B

# %%
print('prediction A :')
print(model.predict(A))
print('prédiction B :')
print(model.predict(B))

plt.figure(figsize=(8, 8))
#plt.subplots_adjust(bottom=0.05, top=0.9, left=0.05, right=0.95)

ax =plt.subplot(111)
plt.title("2 classes", fontsize="small")

#print(A)
plt.scatter(X1[:, 0], X1[:, 1], marker="o",c=Y1, s=35, edgecolor="k")
plt.scatter(A[0][0], A[0][1], marker="o",c='red', s=40, edgecolor="red")
plt.scatter(B[0][0], B[0][1], marker="o",c='blue', s=40, edgecolor="blue")

#Prédire les nombres
liste_x= np.linspace(-6,2, num =50)
xe = np.array([[x] for x in liste_x])
Ylim = (-xe*1.0792954 - 2.191928)/(-0.56038827)

plt.plot(xe,Ylim,color = 'r')
#model.summary()
plt.show()
# Out:
# prediction A :
# 1/1 [==============================] - 0s 37ms/step
# [[0.9366059]]
# prédiction B :
# 1/1 [==============================] - 0s 40ms/step
# [[0.3352631]]

# %% [markdown]
# # Visualisons l'évolution des erreurs et de la précision du modèle sur les données d'entrainement

# %%
# list all data in history

# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(history.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(history.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# # Exemple avec 3 classes ...
#
# * Combien de neurones doit comporter la couche d'entrée pour obtenir un résultat convenable ?
# Essayer de modifier le nombre de neurones de la couche d'entrée....
# La couche de sortie doit comporter obligatoirement 3 neurones car on utilise la fonction d'activation softmax et il y a 3 classes

# %%
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras import initializers
from keras.optimizers import SGD, Adam
from keras.utils import to_categorical
import numpy as np
#from sklearn.cluster import kmeans_plusplus
from sklearn.datasets import make_blobs

# Generate sample data
n_samples = 4000
n_components = 3

X, y_true = make_blobs(
    n_samples=n_samples, centers=n_components, cluster_std=0.60, random_state=0
)

print('y_true :')
print(y_true)
#my_init = initializers.Zeros()
my_init = initializers.Ones()
#my_init = initializers.RandomUniform(minval=0.0, maxval=1.0)

model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=128,input_shape=[2],activation= 'relu',kernel_initializer = my_init))
#La couche de sortie, units vaut 3 mais activation softmax
model.add(Dense(units=3, activation='softmax'))

#Optimisation du réseau ("adam "alternatif à "sgd")
#opt = SGD(lr=0.01) #w = w - learning_rate * g
opt = Adam(learning_rate=0.01)
hist = model.compile(loss='categorical_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  3 (3 classes)
sortie = to_categorical(y_true) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 0 0
# 1 >  1 0 0    vecteur (y_true) > matrice binaire (sortie)
# 2 >  0 1 0


#Entraînement du réseau ? passages
model.fit(x=entree,y=sortie,epochs=20,verbose =0)

#Print weights
#print("")
#print("Weights: \n")
#print(model.get_weights())

#Prediction
A= [[2,2.1]]
B= [[-2,3]]
C= [[0,3.2]]
Apred = model.predict(A)
Bpred = model.predict(B)
Cpred = model.predict(C)

#Affichage des prédictions
#print(model.predict(B))
#print(A[0][1])

print('prediction A :')
print(f"[{Apred[0][0]:.2f},{Apred[0][1]:.2f},{Apred[0][2]:.2f}]")

print('prédiction B :')
print(f"[{Bpred[0][0]:.2f},{Bpred[0][1]:.2f},{Bpred[0][2]:.2f}]")

print('prédiction C :')
print(f"[{Cpred[0][0]:.2f},{Cpred[0][1]:.2f},{Cpred[0][2]:.2f}]")

# Tracés des points avec les prédistions pour A, B et C
plt.figure(figsize=(8, 8))
plt.subplot(111)

#colors = ["#4EACC5", "#FF9C34", "#4E9A06"]
colors = ["red", "green", "blue"]

for k, col in enumerate(colors):# k index , col couleur
    cluster_data = (y_true == k)# cluster succession de valeurs vraies ou fausses
    plt.scatter(X[cluster_data, 0], X[cluster_data, 1], c=col, marker=".", s=10)# X[cluster_data, 0] prend les valeurs X[i,0] pour lesquelles cluster_data[i]=True
plt.scatter(A[0][0], A[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(B[0][0], B[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.scatter(C[0][0], C[0][1], marker="o",c='orange', s=55, edgecolor="k", lw=1.5)
plt.text(2, 1.6, f"[{Apred[0][0]:.1f},{Apred[0][1]:.1f},{Apred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(-2, 2.6, f"[{Bpred[0][0]:.1f},{Bpred[0][1]:.1f},{Bpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')
plt.text(0, 3.5, f"[{Cpred[0][0]:.1f},{Cpred[0][1]:.1f},{Cpred[0][2]:.1f}]", fontsize = 12, backgroundcolor ='orange', ha ='center', c ='black')

plt.title("3 classes", fontsize="small")
plt.show()
# Out:
# y_true :
# [2 2 0 ... 0 2 1]
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 32ms/step
# prediction A :
# [0.00,1.00,0.00]
# prédiction B :
# [0.00,0.00,1.00]
# prédiction C :
# [0.06,0.00,0.94]

# %% [markdown]
# # Traçons les différents domaines ....

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=200,alpha=0.2,seuil=0.45):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha),(0, 0, 1,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        bounds = [0, 0.5, 1]
        norm = mpl.colors.BoundaryNorm(bounds, cmap.N)
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)

    for i in range(0,3):
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.1f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    ax.scatter(X[:,0], X[:,1], c=y, lw=1,marker=".", s=10)

    return fig, ax

plot_decision_boundary2(entree, sortie, model, alpha=0.2)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, sortie, model, alpha=0.2,seuil = 0.8)
# Out:
# 1250/1250 [==============================] - 1s 853us/step
# 1250/1250 [==============================] - 1s 851us/step
# 1250/1250 [==============================] - 1s 892us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)

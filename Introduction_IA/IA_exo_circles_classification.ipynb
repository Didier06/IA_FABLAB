# %% [markdown]
# # Classification avec deux distributions circulaires

# %%
## space for importing required libraries
from sklearn.datasets import make_classification, make_circles #libraries to generate data
import matplotlib.pyplot as plt # importing library to plot
import numpy as np #numpy library for data manipulation and plotting

# %% [markdown]
# # génération et affichage des 2 classes

# %%
np.random.seed(4)
numPoints = 200
X, y = make_circles(n_samples=numPoints,
  factor=.5, noise=.05) #function to yield non circle data provided by sklearn
X = 10 * X

f, ax = plt.subplots(figsize=(8, 6)) #plotting data
ax.scatter(X[:,0],X[:,1], c=y, s=50,cmap="RdBu")
plt.show()

# %% [markdown]
# # Création du réseau de neurones.
# ### Trois couches 10 , 10 et 2 neurones
# Créer le réseau en complétant le code ci-dessous.
# Il nous faudrait la fonction activation sigmoid, et pour la couche de sortie la fonction softmax.

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
# complétez ici pour créer le réseau de neurones
#Trois couches 10 , 10 et 2 neurones
#activation sigmoid, sigmoid et softmax pour la couche de sortie.


model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=10,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))
#Couches intermédiaires
model.add(Dense(units=10,activation= 'sigmoid'))
#La couche de sortie, units vaut 2 mais activation softmax
model.add(Dense(units=2, activation='softmax'))



#Optimiseur SGD ou adam ("adam "alternatif à "sgd")
#opt = SGD(learning_rate=0.01) #w = w - learning_rate * grad
opt = Adam(learning_rate=0.01)
model.compile(loss='mean_squared_error',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  2 (2 classes)
sortie = to_categorical(y) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 1
# 1 >  1 0     vecteur (y_true) > matrice binaire (sortie)

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 2ms/step - loss: 0.2551 - accuracy: 0.4750
# Epoch 2/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2508 - accuracy: 0.4750
# Epoch 3/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.4900
# Epoch 4/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.5100
# Epoch 5/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.5250
# Epoch 6/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.5050
# Epoch 7/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2495 - accuracy: 0.4900
# Epoch 8/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.5000
# Epoch 9/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2499 - accuracy: 0.5200
# Epoch 10/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.5000
# Epoch 11/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2507 - accuracy: 0.4700
# Epoch 12/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.5050
# Epoch 13/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2517 - accuracy: 0.5100
# Epoch 14/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2485 - accuracy: 0.5300
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.5300
# Epoch 16/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2467 - accuracy: 0.5400
# Epoch 17/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2471 - accuracy: 0.5300
# Epoch 18/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.6000
# Epoch 19/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.5000
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2433 - accuracy: 0.6100
# Epoch 21/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.5650
# Epoch 22/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.5950
# Epoch 23/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.6050
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.6050
# Epoch 25/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2380 - accuracy: 0.6050
# Epoch 26/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2363 - accuracy: 0.6300
# Epoch 27/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2342 - accuracy: 0.7100
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.6350
# Epoch 29/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2273 - accuracy: 0.6050
# Epoch 30/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2237 - accuracy: 0.5950
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2179 - accuracy: 0.6350
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.7100
# Epoch 33/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.7150
# Epoch 34/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.6950
# Epoch 35/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.7200
# Epoch 36/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.7350
# Epoch 37/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1829 - accuracy: 0.7350
# Epoch 38/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1729 - accuracy: 0.8050
# Epoch 39/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1612 - accuracy: 0.8250
# Epoch 40/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1441 - accuracy: 0.9100
# Epoch 41/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.9900
# Epoch 42/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1033 - accuracy: 1.0000
# Epoch 43/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0852 - accuracy: 1.0000
# Epoch 44/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0715 - accuracy: 1.0000
# Epoch 45/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0581 - accuracy: 1.0000
# Epoch 46/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 1.0000
# Epoch 47/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 48/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 49/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 50/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 1.0000
# Epoch 51/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 52/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 54/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 55/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 56/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 57/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 58/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 59/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 60/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 61/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 62/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 63/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 64/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 65/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 66/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 67/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 68/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 69/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 70/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 71/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 72/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 73/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 74/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 75/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 76/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 77/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 78/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 79/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 80/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 81/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 82/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 83/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 84/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 85/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 86/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 87/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 88/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 89/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 90/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 91/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 92/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 93/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 95/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 96/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 98/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 99/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 100/100
# 7/7 [==============================] - 0s 1ms/step - loss: 0.0015 - accuracy: 1.0000

# %% [markdown]
# ## Tracé des différents domaines....

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, model, steps=250,alpha=0.2,seuil=0.51):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    steps = steps
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    #fig, ax = plt.subplots()
    for i in range(0,2): 
        #labels1= labels[:,i]
        #print(labels1)
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.2f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    #print(y)
    ax.scatter(X[:,0], X[:,1], c= y,lw=1,marker=".", s=50,cmap="RdBu")
    
    return fig, ax

plot_decision_boundary2(entree, sortie[:,0], model, alpha=0.2, seuil=0.5)
plot_decision_boundary2(entree, y, model, alpha=0.2,seuil = 0.6)
plot_decision_boundary2(entree, y, model, alpha=0.2,seuil = 0.9)
# Out:
# 1954/1954 [==============================] - 2s 873us/step
# 1954/1954 [==============================] - 2s 885us/step
# 1954/1954 [==============================] - 2s 906us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)

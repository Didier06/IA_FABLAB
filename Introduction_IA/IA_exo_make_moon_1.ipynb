# %%
## space for importing required libraries
from sklearn.datasets import make_classification, make_circles #libraries to generate data
from sklearn import datasets
import matplotlib.pyplot as plt # importing library to plot
import numpy as np #numpy library for data manipulation and plotting

# %%
np.random.seed(0)
numPoints = 200
X, y = datasets.make_moons(numPoints, noise=0.10)

X = 10 * X

f, ax = plt.subplots(figsize=(8, 6)) #plotting data
ax.scatter(X[:,0],X[:,1], c=y, s=50,cmap="bwr")
plt.show()

# %% [markdown]
# # Création du réseau de neurones.
# ### Modifier le réseau ci-dessous pour le rendre plus performant

# %%
from keras.models import Sequential 
from keras.layers import Activation, Dense 
from keras import initializers
from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
import numpy as np 

#my_init = initializers.Zeros() 
my_init = initializers.Ones()
# Modifiez ici vos réseaux de neuronespour améliorer sa performance et donc séparer les 2 classes correctement.
model=Sequential()
#pour La couche d'entrée, input_shape vaut : 2  (car on a 2 features: x et y), pas de normalisation nécessaire
model.add(Dense(units=2,input_shape=[2],activation= 'sigmoid',kernel_initializer = my_init))
#Couches intermédiaires

#La couche de sortie, units vaut 2 mais activation softmax
model.add(Dense(units=2, activation='softmax'))

#Optimiseur SGD ou adam ("adam "alternatif à "sgd")
#opt = SGD(learning_rate=0.01) #w = w - learning_rate * grad
opt = Adam(learning_rate=0.1)
model.compile(loss='binary_crossentropy',optimizer=opt,  metrics=['accuracy'])
# entrée de dimension 2 (x, y)
entree = X
# y_true de dimension  2 (2 classes)
sortie = to_categorical(y) #Converts a class vector (integers) to binary class matrix.
# 0 >  0 1
# 1 >  1 0     vecteur (y_true) > matrice binaire (sortie)

#Entraînement du réseau 100 passages
history = model.fit(x=entree,y=sortie,epochs=100, batch_size=20)
print(f"précision obtenue : {history.history['accuracy'][-1]:.3f}")
model.predict([[0, 5],[1,9]])

# performance du réseau
# Représentation d'un nuage de points

fig, ax1 = plt.subplots(figsize=(6, 4))
ax2 = ax1.twiny()

plt.title('modèle pertes et précision')
ax1.plot(history.history['loss'], 'g-', label = 'loss')
ax1.set_ylabel('loss')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper left')
ax2 = ax1.twinx()

ax2.plot(history.history['accuracy'], 'b-', label ='accuracy')
ax2.set_ylabel('accuracy')
ax2.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 1ms/step - loss: 0.7321 - accuracy: 0.6250
# Epoch 2/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5942 - accuracy: 0.6800
# Epoch 3/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4719 - accuracy: 0.8750
# Epoch 4/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.8850
# Epoch 5/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3779 - accuracy: 0.8750
# Epoch 6/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3445 - accuracy: 0.8850
# Epoch 7/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3403 - accuracy: 0.8700
# Epoch 8/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3403 - accuracy: 0.8850
# Epoch 9/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3250 - accuracy: 0.8900
# Epoch 10/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3292 - accuracy: 0.8800
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3191 - accuracy: 0.8850
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8850
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8850
# Epoch 14/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3186 - accuracy: 0.8900
# Epoch 15/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3249 - accuracy: 0.8800
# Epoch 16/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3163 - accuracy: 0.8950
# Epoch 17/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3125 - accuracy: 0.8850
# Epoch 18/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.8800
# Epoch 19/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3163 - accuracy: 0.8800
# Epoch 20/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3079 - accuracy: 0.8850
# Epoch 21/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3024 - accuracy: 0.8850
# Epoch 22/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3036 - accuracy: 0.8900
# Epoch 23/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3053 - accuracy: 0.8900
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3059 - accuracy: 0.8900
# Epoch 25/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2964 - accuracy: 0.8900
# Epoch 26/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2974 - accuracy: 0.8900
# Epoch 27/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.8900
# Epoch 28/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2989 - accuracy: 0.8850
# Epoch 29/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3021 - accuracy: 0.8850
# Epoch 30/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2941 - accuracy: 0.8900
# Epoch 31/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2980 - accuracy: 0.8850
# Epoch 32/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.8950
# Epoch 33/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3040 - accuracy: 0.8850
# Epoch 34/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2929 - accuracy: 0.8850
# Epoch 35/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2949 - accuracy: 0.8850
# Epoch 36/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2997 - accuracy: 0.8900
# Epoch 37/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2943 - accuracy: 0.8900
# Epoch 38/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2950 - accuracy: 0.8800
# Epoch 39/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2926 - accuracy: 0.8950
# Epoch 40/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2939 - accuracy: 0.8950
# Epoch 41/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2931 - accuracy: 0.8900
# Epoch 42/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2920 - accuracy: 0.8850
# Epoch 43/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3005 - accuracy: 0.8850
# Epoch 44/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2900 - accuracy: 0.8900
# Epoch 45/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2937 - accuracy: 0.8850
# Epoch 46/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3005 - accuracy: 0.8800
# Epoch 47/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2870 - accuracy: 0.8900
# Epoch 48/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2904 - accuracy: 0.8750
# Epoch 49/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2930 - accuracy: 0.8800
# Epoch 50/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2924 - accuracy: 0.8950
# Epoch 51/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2935 - accuracy: 0.8950
# Epoch 52/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.8950
# Epoch 53/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2953 - accuracy: 0.8950
# Epoch 54/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2905 - accuracy: 0.8900
# Epoch 55/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2942 - accuracy: 0.8900
# Epoch 56/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2952 - accuracy: 0.8900
# Epoch 57/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.8950
# Epoch 58/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2957 - accuracy: 0.8750
# Epoch 59/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2910 - accuracy: 0.8800
# Epoch 60/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2904 - accuracy: 0.8900
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2890 - accuracy: 0.8950
# Epoch 62/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2952 - accuracy: 0.8850
# Epoch 63/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2923 - accuracy: 0.8900
# Epoch 64/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2900 - accuracy: 0.8850
# Epoch 65/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2911 - accuracy: 0.8900
# Epoch 66/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2881 - accuracy: 0.8900
# Epoch 67/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2887 - accuracy: 0.8850
# Epoch 68/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2965 - accuracy: 0.8850
# Epoch 69/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2936 - accuracy: 0.8900
# Epoch 70/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2959 - accuracy: 0.8850
# Epoch 71/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2967 - accuracy: 0.8850
# Epoch 72/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2942 - accuracy: 0.8900
# Epoch 73/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2991 - accuracy: 0.8800
# Epoch 74/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2965 - accuracy: 0.8750
# Epoch 75/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2975 - accuracy: 0.8950
# Epoch 76/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2897 - accuracy: 0.8900
# Epoch 77/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2940 - accuracy: 0.8950
# Epoch 78/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2930 - accuracy: 0.8850
# Epoch 79/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2921 - accuracy: 0.8900
# Epoch 80/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2896 - accuracy: 0.8900
# Epoch 81/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2951 - accuracy: 0.8900
# Epoch 82/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2931 - accuracy: 0.8900
# Epoch 83/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2985 - accuracy: 0.8850
# Epoch 84/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2886 - accuracy: 0.8900
# Epoch 85/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2934 - accuracy: 0.8850
# Epoch 86/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3075 - accuracy: 0.8650
# Epoch 87/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2991 - accuracy: 0.8700
# Epoch 88/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2926 - accuracy: 0.8850
# Epoch 89/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2920 - accuracy: 0.8900
# Epoch 90/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2929 - accuracy: 0.8950
# Epoch 91/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2890 - accuracy: 0.8950
# Epoch 92/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.8850
# Epoch 93/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3050 - accuracy: 0.8850
# Epoch 94/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2885 - accuracy: 0.8950
# Epoch 95/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2970 - accuracy: 0.8850
# Epoch 96/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2897 - accuracy: 0.8950
# Epoch 97/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2885 - accuracy: 0.8900
# Epoch 98/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2949 - accuracy: 0.8800
# Epoch 99/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2959 - accuracy: 0.8900
# Epoch 100/100
# 10/10 [==============================] - 0s 1ms/step - loss: 0.2889 - accuracy: 0.8850
# précision obtenue : 0.885
# 1/1 [==============================] - 0s 60ms/step

# %% [markdown]
# # Tracé des zones de prédiction

# %%
import matplotlib as mpl
def plot_decision_boundary2(X, y, NbClasses, model, steps=250,alpha=0.4,seuil=0.51):
    """
    Function to plot the decision boundary and data points of a model.
    Data points are colored based on their actual label.
    """
    #alpha = alpha
    colorT = (0, 0, 0.0,0.0)# tranparent
    color2 = [(1, 0, 0,alpha),(0, 1, 0,alpha)]
    def C_map(coul):
        cmap = (mpl.colors.ListedColormap([colorT, coul]))
        return cmap

    # Define region of interest by data limits
    xmin, xmax = X[:,0].min(), X[:,0].max()
    ymin, ymax = X[:,1].min(), X[:,1].max()
    steps = steps
    x_span = np.linspace(xmin, xmax, steps)
    y_span = np.linspace(ymin, ymax, steps)
    xx, yy = np.meshgrid(x_span, y_span)

    # Make predictions across region of interest
    labels = model.predict(np.c_[xx.ravel(), yy.ravel()])
    fig = plt.figure(figsize=(6, 6))
    ax =plt.subplot(111)
    #fig, ax = plt.subplots()
    
    for i in range(0,NbClasses): 
        #labels1= labels[:,i]
        #print(labels1)
        # Plot decision boundary in region of interest
        z = labels[:,i].reshape(xx.shape)
        z = z > seuil #(seuil Threshold value)
        ax.contourf(xx, yy, z, cmap=C_map(color2[i]))
    plt.text(-3, -0.5, f" seuil = {seuil:.2f} ", fontsize = 12, backgroundcolor ='orange', ha ='left', c ='black')
    plt.title("Domaines de décision ...", fontsize="small")
    #print(y)
    ax.scatter(X[:,0], X[:,1], c= y,lw=5,marker=".", s=50,cmap="RdBu")
    
    return fig, ax

plot_decision_boundary2(entree, sortie[:,0], 2, model, alpha=0.4, seuil=0.5)
#plot_decision_boundary2(entree, y, 2, model, alpha=0.2,seuil = 0.6)
#plot_decision_boundary2(entree, y, 2, model, alpha=0.2,seuil = 0.9)
# Out:
# 1954/1954 [==============================] - 2s 877us/step
# (<Figure size 600x600 with 1 Axes>,
#  <Axes: title={'center': 'Domaines de décision ...'}>)

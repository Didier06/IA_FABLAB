# %% [markdown]
# <a href="https://colab.research.google.com/github/Didier06/IA_FABLAB/blob/main/introduction_IA/Yolov8_Minst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================================
# 🧠 MNIST multi-chiffres avec YOLOv8m (Ultralytics)
# ======================================================

# !pip install ultralytics torchvision tqdm pyyaml --quiet

from torchvision import datasets
from PIL import Image
import random, os, yaml
from tqdm import tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.8 MB/s eta 0:00:00

# %%
# ======================================================
# 1️⃣ Monter Google Drive pour sauvegarder le modèle
# ======================================================
from google.colab import drive
drive.mount('/content/drive')

save_dir = "/content/drive/MyDrive/MNIST_YOLOv8m"
os.makedirs(save_dir, exist_ok=True)
print(f"📁 Modèle sera sauvegardé dans : {save_dir}")
# Out:
# Mounted at /content/drive
# 📁 Modèle sera sauvegardé dans : /content/drive/MyDrive/MNIST_YOLOv8m

# %%
# ======================================================
# 2️⃣ Génération du dataset multi-chiffres (3 à 10)
# ======================================================
mnist = datasets.MNIST(root="data", train=True, download=True)

os.makedirs("mnist_yolo/images/train", exist_ok=True)
os.makedirs("mnist_yolo/labels/train", exist_ok=True)
os.makedirs("mnist_yolo/images/val", exist_ok=True)
os.makedirs("mnist_yolo/labels/val", exist_ok=True)

def create_images(nb_images, split):
    for i in tqdm(range(nb_images), desc=f"Génération {split}"):
        img = Image.new("L", (320, 320), color=0)
        nb_digits = random.randint(3, 10)
        label_lines = []

        for _ in range(nb_digits):
            idx = random.randint(0, len(mnist) - 1)
            digit_img, label = mnist[idx]
            x = random.randint(0, 320 - 28)
            y = random.randint(0, 320 - 28)
            img.paste(digit_img, (x, y))

            xc = (x + 14) / 320
            yc = (y + 14) / 320
            w = 28 / 320
            h = 28 / 320
            label_lines.append(f"{label} {xc:.6f} {yc:.6f} {w:.6f} {h:.6f}")

        img.save(f"mnist_yolo/images/{split}/{i}.jpg")
        with open(f"mnist_yolo/labels/{split}/{i}.txt", "w") as f:
            f.write("\n".join(label_lines))

create_images(4000, "train")
create_images(1000, "val")
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 6.11MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 161kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.52MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.93MB/s]
# Génération train: 100%|██████████| 4000/4000 [00:02<00:00, 1528.70it/s]
# Génération val: 100%|██████████| 1000/1000 [00:00<00:00, 1592.60it/s]

# %%
# ======================================================
# 3️⃣ Fichier de configuration data.yaml
# ======================================================
import yaml

with open("mnist_yolo/data.yaml", "w") as f:
    yaml.dump({
        'path': '/content/mnist_yolo',  # dossier racine du dataset
        'train': 'images/train',
        'val': 'images/val',
        'nc': 10,
        'names': [str(i) for i in range(10)]
    }, f)

print("✅ Dataset YOLOv8 prêt")
# Out:
# ✅ Dataset YOLOv8 prêt

# %%
# !nvidia-smi
# Out:
# Tue Oct 21 08:51:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# ======================================================
# 🔁 Entraînement YOLOv8m avec vraie reprise Drive (même dossier, même epoch)
# ======================================================
import os
from ultralytics import YOLO
from google.colab import drive

# 1️⃣ Monter Google Drive
drive.mount('/content/drive')

# 2️⃣ Paramètres
drive_dir = '/content/drive/MyDrive/yolo_mnist_training'
run_name  = 'mnist_yolo_run'
data_yaml = '/content/mnist_yolo/data.yaml'  # chemin de ton YAML
base_model = 'yolov8m.pt'
img_size = 320
epochs_total = 50

# 3️⃣ Dossier de run complet
run_dir = f"{drive_dir}/{run_name}"
os.makedirs(run_dir, exist_ok=True)

# 4️⃣ Vérifie s’il y a un checkpoint existant
last_ckpt = os.path.join(run_dir, 'weights', 'last.pt')

if os.path.exists(last_ckpt):
    print(f"🔁 Reprise automatique depuis : {last_ckpt}")
    model = YOLO(last_ckpt)
    resume_mode = True
else:
    print("🆕 Nouveau départ avec yolov8m.pt")
    model = YOLO(base_model)
    resume_mode = False

# 5️⃣ Entraînement avec vraie reprise native
results = model.train(
    data=data_yaml,
    epochs=epochs_total,
    imgsz=img_size,
    project=drive_dir,     # <-- ton Drive comme projet
    name=run_name,         # <-- même nom de run (critique)
    resume=resume_mode,    # ✅ permet à YOLO de reprendre dans le même dossier
    save_period=2,         # ✅ sauvegarde tous les 5 epochs
    exist_ok=True,         # ✅ évite la création de _2, _3, _8
    device=0               # GPU unique (Colab)
)

print("✅ Entraînement terminé ou repris avec succès !")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔁 Reprise automatique depuis : /content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/weights/last.pt
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/mnist_yolo/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=mnist_yolo_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolo_mnist_training, rect=False, resume=/content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run, save_frames=False, save_json=False, save_period=2, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3781486  ultralytics.nn.modules.head.Detect           [10, [192, 384, 576]]
# Model summary: 169 layers, 25,862,110 parameters, 25,862,094 gradients, 79.1 GFLOPs
#
# Transferred 475/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 193.2±87.1 MB/s, size: 2.8 KB)
# train: Scanning /content/mnist_yolo/labels/train.cache... 4000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4000/4000 8.6Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 73.8±51.6 MB/s, size: 2.7 KB)
# val: Scanning /content/mnist_yolo/labels/val.cache... 1000 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1000/1000 182.8Kit/s 0.0s
# Plotting labels to /content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/weights/last.pt from epoch 3 to 50 total epochs
# Image sizes 320 train, 320 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.59G     0.7414     0.5639     0.8419        136        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.9it/s 5.5s
#                    all       1000       6526      0.966      0.934      0.979      0.804
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      4.59G     0.6968     0.4992     0.8326        149        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.956      0.937       0.98      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.59G     0.6524     0.4995     0.8243        130        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.6it/s 5.7s
#                    all       1000       6526      0.974      0.938      0.983      0.843
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      4.59G     0.6433     0.4816     0.8199        165        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.9it/s 5.5s
#                    all       1000       6526      0.975      0.941      0.985      0.803
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      4.59G     0.6053     0.4576     0.8142        148        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526       0.97      0.946      0.986      0.863
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      4.59G     0.5932      0.444     0.8122        135        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.4s
#                    all       1000       6526      0.977      0.945      0.987       0.87
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      4.59G     0.5775     0.4364     0.8098        127        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.4s
#                    all       1000       6526      0.982      0.952      0.989      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      4.59G     0.5694     0.4186     0.8088        107        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.981      0.954      0.989      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      4.59G     0.5533     0.3954     0.8062        144        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.973      0.942      0.986      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      4.59G     0.5464     0.4058     0.8067        160        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.4s
#                    all       1000       6526       0.98      0.949      0.989      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      4.59G     0.5506     0.3985     0.8051        158        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.983      0.949       0.99      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      4.65G     0.5317     0.3824     0.8048        164        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.4s
#                    all       1000       6526      0.985      0.951       0.99      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      4.65G      0.524     0.3767     0.8027        176        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.977      0.947      0.989      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      4.65G     0.5168     0.3827     0.8022        117        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.978      0.954      0.989      0.875
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      4.65G     0.5032     0.3635      0.801        144        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.983      0.959       0.99      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      4.65G     0.5027     0.3579     0.8004        148        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.984       0.96      0.991      0.882
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      4.65G     0.4941     0.3596     0.7979        115        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.979      0.961       0.99      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      4.65G     0.4956     0.3503     0.7995        125        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.983      0.955       0.99      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      4.65G     0.4743     0.3429     0.7964        115        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.982      0.962       0.99      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      4.65G     0.4783     0.3436     0.7987        138        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.985      0.954       0.99      0.866
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      4.65G     0.4773       0.34     0.7968        174        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.982      0.965      0.991      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      4.65G     0.4675     0.3368      0.796        133        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.988      0.958      0.992      0.914
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      4.65G     0.4691     0.3341     0.7969        186        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.7it/s 5.6s
#                    all       1000       6526      0.985      0.961      0.991      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      4.65G     0.4592     0.3255     0.7945        117        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.4s
#                    all       1000       6526      0.981      0.961      0.991      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      4.65G      0.454     0.3232     0.7943        156        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.985      0.961       0.99      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      4.65G     0.4462     0.3172     0.7944        123        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.4s
#                    all       1000       6526      0.987      0.958      0.991      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      4.65G     0.4499     0.3214     0.7935        163        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.983      0.961       0.99      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      4.65G     0.4401     0.3133     0.7958        134        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.984      0.962      0.991      0.908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      4.65G     0.4436     0.3121     0.7932        171        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.984      0.963      0.992       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      4.65G     0.4302     0.3051      0.792        129        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.988       0.96      0.992      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      4.65G     0.4273     0.3027     0.7923        146        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.985      0.964      0.992      0.919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      4.65G     0.4273     0.2995     0.7917        114        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.988      0.963      0.992      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      4.65G     0.4191     0.3013     0.7913        144        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.987      0.963      0.992      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      4.65G     0.4157      0.295     0.7919        139        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.1it/s 5.3s
#                    all       1000       6526      0.985      0.966      0.992      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      4.65G      0.412     0.2827     0.7899        140        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.984      0.966      0.991      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      4.65G     0.4093     0.2846     0.7894        124        320: 100% ━━━━━━━━━━━━ 250/250 6.4it/s 38.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526      0.989      0.966      0.992       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.65G     0.4064     0.2832     0.7897        170        320: 100% ━━━━━━━━━━━━ 250/250 6.5it/s 38.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 6.0it/s 5.3s
#                    all       1000       6526       0.99      0.963      0.992      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      4.65G     0.3985     0.2807     0.7918        111        320: 47% ━━━━━╸────── 117/250 6.3it/s 18.4s<21.0s

# %%
# ======================================================
# 5️⃣ Visualisation des courbes (loss et mAP)
# ======================================================
import pandas as pd
import matplotlib.pyplot as plt

# Chemin vers ton dossier de run sur Google Drive
metrics_path = "/content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/results.csv"

# Lecture du fichier CSV
df = pd.read_csv(metrics_path)

# --- Visualisation ---
plt.figure(figsize=(12,5))

# Pertes (Loss)
plt.subplot(1,2,1)
plt.plot(df['epoch'], df['train/box_loss'], label='Box Loss')
plt.plot(df['epoch'], df['train/cls_loss'], label='Class Loss')
plt.plot(df['epoch'], df['train/dfl_loss'], label='DFL Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Courbes de perte (Loss)')
plt.legend()

# Précision (mAP)
plt.subplot(1,2,2)
plt.plot(df['epoch'], df['metrics/mAP50'], label='mAP@50')
plt.plot(df['epoch'], df['metrics/mAP50-95'], label='mAP@50-95')
plt.xlabel('Epoch')
plt.ylabel('mAP')
plt.title('Précision moyenne (mAP)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# ======================================================
# 6️⃣ Test de prédiction (sur ton modèle sauvegardé sur Drive)
# ======================================================
from ultralytics import YOLO

# Chemin vers le modèle entraîné (best.pt sur ton Drive)
model_path = "/content/drive/MyDrive/yolo_mnist_training/mnist_yolo_run/weights/best.pt"

# Charger le modèle final
model = YOLO(model_path)

# Image de test
test_image = "mnist_yolo/images/val/5.jpg"

# Lancer la prédiction et sauvegarder le résultat
results = model.predict(source=test_image, save=True, imgsz=320)

# Afficher la prédiction directement dans Colab
results[0].show()

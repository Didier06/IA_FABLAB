# %% [markdown]
# ## Convolution 1D

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Fonction pour visualiser les graphes**

# %%
 #Visualisation

def affichage_convolution(f,g,mode='same'):
	h = np.convolve(f,g,mode=mode)

	ax = plt.subplot(2,1,1)
	ax.set_title("fonction d'entrée f ")
	plt.plot(f)


	ax = plt.subplot(2,1,2)
	ax.set_title("Convolutio h = f*g")
	plt.plot(h,color='red')

	plt.subplots_adjust(top=0.9, bottom=0.1, left=0.1, right=0.95, hspace=1.0,wspace=0.5)
	# plt.tight_layout()
	# plt.savefig('convolution-1d-2.png')
	plt.show()
	return

# %% [markdown]
# **Exemple de convolution d'un signal bruité**

# %%
# Exemple : moyenne mobile et bruit
N = 100
f = np.sin(np.linspace(0,2*np.pi,N)) + 1*np.random.random(N)
g = 1/5*np.ones(5)
affichage_convolution(f,g,mode='same')

# %% [markdown]
# ***la convolution a permis de diminuer le bruit du signal***
